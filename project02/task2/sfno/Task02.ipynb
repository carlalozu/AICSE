# %%
# %load_ext autoreload
# %autoreload 2

# %%
from trainer import Trainer

# %%
import matplotlib.pyplot as plt

# %%
n_train = 50
modesx = 32
modesy = 32
width = 64
trainer = Trainer(n_train, modesx, modesy, width)
# Out:
# Loading train dataloader at resolution (32, 64) with 10 samples and batch-size=4
# Loading test dataloader at resolution (32, 64) with 50 samples and batch-size=10
# Loading test dataloader at resolution (64, 128) with 50 samples and batch-size=10

# %%
trainer.plot_inputs(0)

# %% [markdown]
# ## Training

# %%
learning_rate = 8e-4
epochs = 10

# %%
trainer.train(epochs=epochs, learning_rate=learning_rate)
# Out:
# ######### Epoch: 0  ######### Train Loss: 0.48032665252685547  ######### Relative L2 Test Norm: 10224.340148925781
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 trainer.train(epochs=epochs, learning_rate=learning_rate)
#
# File ~/Documents/Courses/Spring2024/AICSE/project02/task2/sfno/trainer.py:117, in Trainer.train(self, epochs, learning_rate)
#     115 output_pred_batch = self.fno(input_batch).squeeze(2)
#     116 loss_f = loss(output_pred_batch, output_batch)
# --> 117 loss_f.backward()
#     118 optimizer.step()
#     119 train_mse += loss_f.item()
#
# File /opt/homebrew/anaconda3/envs/aicse/lib/python3.9/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
# ...

# %% [markdown]
# ## Plot

# %%
trainer.plot()
# Out:
# /Users/carla/Documents/Courses/Spring2024/AICSE/project02/task2/sfno/trainer.py:181: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure(figsize=(7, 7))
for index, resolution in enumerate([(32, 64), (64, 128)]):
    for inputs, outputs in trainer.testing_set[resolution]:
        # output_pred_batch = self.fno(inputs).squeeze(2)
        # output_pred_batch = output_pred_batch.detach().cpu().numpy()

        ax = fig.add_subplot(2, 3, index*3 + 1)
        ax.imshow(inputs[0,0,:,:])
        ax.set_title(f'Input x {resolution}')
        plt.xticks([], [])
        plt.yticks([], [])

        ax = fig.add_subplot(2, 3, index*3 + 2)
        ax.imshow(outputs[0,0,:,:])
        ax.set_title('Ground-truth y')
        plt.xticks([], [])
        plt.yticks([], [])

# %%
inputs.shape
# Out:
# torch.Size([10, 3, 32, 64])
